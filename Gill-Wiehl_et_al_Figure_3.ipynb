# %%
#import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# This is the total over-crediting method:

# %%
df_all_results=pd.read_excel('df_all_results_table.xlsx')
df_all_except_aus_results=pd.read_excel('df_all_except_aus_results_table.xlsx')
df_adoption_results=pd.read_excel('df_adoption_results_table.xlsx')
df_usage_results=pd.read_excel('df_usage_results_table.xlsx')
df_stacking_results=pd.read_excel('df_stacking_results_table.xlsx')
df_fNRB_results=pd.read_excel('df_fNRB_results_table.xlsx')
df_firewood_charcoal_results=pd.read_excel('df_only_charcoal_results_table.xlsx')
df_only_EF_results=pd.read_excel('df_EF_only_results_table.xlsx')
df_adjusted_results=pd.read_excel('df_adjusted_results_table.xlsx')
df_rebound_results=pd.read_excel('df_rebound_results_table.xlsx')

results_category = ['All', 'GS-Metered-Pellets', 'GS-LPG', 'GS-Firewood','GS-Simplified-Firewood','GS-Charcoal',
                     'CDM-Firewood','CDM-Charcoal','AMS-I-E-Ethanol','Bangladesh',
                     'Burkinafaso','Cameroon','China','Ethiopia','Ghana','Guatemala','Haiti','Honduras',
                     'India', 'Kenya','Lesotho','Malawi','Mali','Mexico','Mozambique','Myanmar',
                     'Nepal','Nigeria','Peru','Rwanda','Sudan','Uganda','Zambia']
results_all=df_all_results.iloc[:,2]
results_except_aus=df_all_except_aus_results.iloc[:,2]
results_adoption=df_adoption_results.iloc[:,2]
results_usage=df_usage_results.iloc[:,2]
results_stacking=df_stacking_results.iloc[:,2]
results_fNRB=df_fNRB_results.iloc[:,2]
results_firewood_charcoal=df_firewood_charcoal_results.iloc[:,2]
results_only_EF=df_only_EF_results.iloc[:,2]
results_adjusted=df_adjusted_results.iloc[:,2]
results_rebound=df_rebound_results.iloc[:,2]

df_comparing_all_results_table= pd.DataFrame([results_category,results_all, results_except_aus, results_adoption, results_usage, results_stacking,results_fNRB,results_firewood_charcoal,results_only_EF, results_adjusted, results_rebound],index=['category','all','all except','adoption','usage','stacking','fNRB','firewood-charcoal','Only EF','Adjusted Consumption','rebound'])

df_comparing_all_results_table
#df_all_results.iloc[1,3] [row,column] 1 is lower 2 is mean 3 is upper
# Out:
#                         0                   1       2            3   \
# category               All  GS-Metered-Pellets  GS-LPG  GS-Firewood
# all                   9.21                 1.5     5.9          8.9
# all except             3.4                1.25    2.48         2.35
# adoption              1.36                 1.0    1.52         2.54
# usage                 1.43                 1.0    1.36         1.37
# stacking               1.1                 1.0     1.0          1.0
# fNRB                  1.69                2.67    1.62         1.24
# firewood-charcoal     1.54                 1.0     1.0         1.03
# Only EF               0.64                0.87    1.82         1.19
# Adjusted Consumption   1.4                 1.0    1.09         1.52
# rebound               1.04                1.28     1.0          1.0
#
#                                           4            5             6   \
# category              GS-Simplified-Firewood  GS-Charcoal  CDM-Firewood
# ...

# %% [markdown]
# This is the analysis at the lowest level of granularity (monitoring report or stove cohort)

# %%
df_all_results_v1=pd.read_excel('df_all_results_table_v1.xlsx')
df_all_except_aus_results_v1=pd.read_excel('df_all_except_aus_results_table_v1.xlsx')
df_adoption_results_v1=pd.read_excel('df_adoption_results_table_v1.xlsx')
df_usage_results_v1=pd.read_excel('df_usage_results_table_v1.xlsx')
df_stacking_results_v1=pd.read_excel('df_stacking_results_table_v1.xlsx')
df_fNRB_results_v1=pd.read_excel('df_fNRB_results_table_v1.xlsx')
df_firewood_charcoal_results_v1=pd.read_excel('df_only_charcoal_results_table_v1.xlsx')
df_only_EF_results_v1=pd.read_excel('df_EF_only_results_table_v1.xlsx')
df_adjusted_results_v1=pd.read_excel('df_adjusted_results_table_v1.xlsx')
df_rebound_results_v1=pd.read_excel('df_rebound_results_table_v1.xlsx')

results_category = ['All', 'GS-Metered-Pellets', 'GS-LPG', 'GS-Firewood','GS-Simplified-Firewood','GS-Charcoal',
                     'CDM-Firewood','CDM-Charcoal','AMS-I-E-Ethanol','Bangladesh',
                     'Burkinafaso','Cameroon','China','Ethiopia','Ghana','Guatemala','Haiti','Honduras',
                     'India', 'Kenya','Lesotho','Malawi','Mali','Mexico','Mozambique','Myanmar',
                     'Nepal','Nigeria','Peru','Rwanda','Sudan','Uganda','Zambia']
results_all_v1=df_all_results_v1.iloc[:,2]
results_except_aus_v1=df_all_except_aus_results_v1.iloc[:,2]
results_adoption_v1=df_adoption_results_v1.iloc[:,2]
results_usage_v1=df_usage_results_v1.iloc[:,2]
results_stacking_v1=df_stacking_results_v1.iloc[:,2]
results_fNRB_v1=df_fNRB_results_v1.iloc[:,2]
results_firewood_charcoal_v1=df_firewood_charcoal_results_v1.iloc[:,2]
results_only_EF_v1=df_only_EF_results_v1.iloc[:,2]
results_adjusted_v1=df_adjusted_results_v1.iloc[:,2]
results_rebound_v1=df_rebound_results_v1.iloc[:,2]

df_comparing_all_results_table_v1= pd.DataFrame([results_category,results_all_v1, results_except_aus_v1, results_adoption_v1, results_usage_v1, results_stacking_v1,results_fNRB_v1,results_firewood_charcoal_v1,results_only_EF_v1, results_adjusted_v1, results_rebound_v1],index=['category','all','all except','adoption','usage','stacking','fNRB','firewood-charcoal','Only EF','Adjusted Consumption','rebound'])

df_comparing_all_results_table_v1
# Out:
#                         0                   1       2            3   \
# category               All  GS-Metered-Pellets  GS-LPG  GS-Firewood
# all                    6.6                1.54    7.95         8.54
# all except             3.4                1.25    2.48         2.35
# adoption              1.36                 1.0     1.3         1.55
# usage                 1.54                 1.0    1.34         1.36
# stacking               1.4                 1.0     1.0          1.0
# fNRB                  2.24                 2.9    2.23          1.8
# firewood-charcoal     1.08                0.89     2.1         1.04
# Only EF               0.83                0.89     2.1         1.04
# Adjusted Consumption  1.94                 1.0    1.01         2.29
# rebound               1.15                1.28     1.0          1.0
#
#                                           4            5             6   \
# category              GS-Simplified-Firewood  GS-Charcoal  CDM-Firewood
# ...

# %%
df_all_results_categories=pd.read_excel('all_results_categories.xlsx')
df_all_except_aus_results_categories=pd.read_excel('all_results_except_aus_categories.xlsx')
df_adoption_results_categories=pd.read_excel('all_results_adoption_categories.xlsx')
df_usage_results_categories=pd.read_excel('all_results_usage_categories.xlsx')
df_stacking_results_categories=pd.read_excel('all_results_stacking_categories.xlsx')
df_fNRB_results_categories=pd.read_excel('all_results_fNRB_categories.xlsx')
df_firewood_charcoal_results_categories=pd.read_excel('all_results_firewood_charcoal_categories.xlsx')
df_only_EF_results_categories=pd.read_excel('all_results_EF_categories.xlsx')
df_adjusted_results_categories=pd.read_excel('all_results_adjusted_categories.xlsx')
df_rebound_results_categories=pd.read_excel('all_results_rebound_categories.xlsx')
category=df_firewood_charcoal_results_categories['category']
results_all_categories=df_all_results_categories.iloc[:,1]
results_except_aus_categories=df_all_except_aus_results_categories.iloc[:,1]
results_adoption_categories=df_adoption_results_categories.iloc[:,1]
results_usage_categories=df_usage_results_categories.iloc[:,1]
results_stacking_categories=df_stacking_results_categories.iloc[:,1]
results_fNRB_categories=df_fNRB_results_categories.iloc[:,1]
results_firewood_charcoal_categories=df_firewood_charcoal_results_categories.iloc[:,1]
results_only_EF_categories=df_only_EF_results_categories.iloc[:,1]
results_adjusted_categories=df_adjusted_results_categories.iloc[:,1]
results_rebound_categories=df_rebound_results_categories.iloc[:,1]

df_comparing_all_results_table_categories= pd.DataFrame([category,results_all_categories, results_except_aus_categories, results_adoption_categories, results_usage_categories, results_stacking_categories,results_fNRB_categories,results_firewood_charcoal_categories,results_only_EF_categories, results_adjusted_categories, results_rebound_categories],index=['category','all','all except','adoption','usage','stacking','fNRB','firewood-charcoal','Only EF','Adjusted Consumption','rebound'])

df_comparing_all_results_table_categories
df_comparing_all_results_table_categories.to_excel('df_comparing_all_results_table_categories.xlsx')

# %%
df_comparing_all_results_table_categories
# Out:
#                                      0                 1         2  \
# category              cdm_imp_charcoal  cdm_imp_firewood   ethanol
# all                          21.039642          23.50299  5.429625
# all except                     2.61788          3.591683  1.762663
# adoption                      1.427435          1.346853  1.575501
# usage                         1.751989          1.981413  1.905162
# stacking                      2.613004          2.462563  0.999977
# fNRB                          2.653547          2.710239   2.90023
# firewood-charcoal             1.317738               1.0  1.364754
# Only EF                       0.623108          0.646205  0.613189
# Adjusted Consumption          2.318084          1.951315  1.021637
# rebound                       1.282042          1.282045  1.282069
#
#                                     3                4         5  \
# category              gs_imp_charcoal  gs_imp_firewood    gs_lpg
# ...

# %%
df_comparing_all_results_table_v1.to_excel('df_comparing_all_results_table_v1.xlsx')
df_comparing_all_results_table.to_excel('df_comparing_all_results_table.xlsx')

# %%
x_all= 1
x_gs_fw= 2
x_gs_simple_fw=3
x_IIG_fw= 4
x_gs_charc=5
x_IIG_charc=6
x_gs_lpg=7
x_IE=8
x_Meter=9

# %%
df_all_all=df_all_results.iloc[0,2]
df_only_fNRB_all=df_fNRB_results.iloc[0,2]
df_only_usage_all=df_usage_results.iloc[0,2]
df_only_emission_all=df_only_EF_results.iloc[0,2]
df_only_emission_charcoal_all=df_firewood_charcoal_results.iloc[0,2]
df_only_emission_adjust_all=df_adjusted_results.iloc[0,2]
df_only_rebound_all=df_rebound_results.iloc[0,2]
df_only_adoption_all=df_adoption_results.iloc[0,2]
df_only_stacking_all=df_stacking_results.iloc[0,2]
df_all_except_aut_all=df_all_except_aus_results.iloc[0,2]





df_all_IE=df_all_results.iloc[8,2]
df_only_fNRB_IE=df_fNRB_results.iloc[8,2]
df_only_usage_IE=df_usage_results.iloc[8,2]
df_only_emission_IE=df_only_EF_results.iloc[8,2]
df_only_emission_charcoal_IE=df_firewood_charcoal_results.iloc[8,2]
df_only_emission_adjust_IE=df_adjusted_results.iloc[8,2]
df_only_rebound_IE=df_rebound_results.iloc[8,2]
df_only_adoption_IE=df_adoption_results.iloc[8,2]
df_only_stacking_IE=df_stacking_results.iloc[8,2]
df_all_except_aut_IE=df_all_except_aus_results.iloc[8,2]



df_all_Meter=df_all_results.iloc[1,2]
df_only_fNRB_Meter=df_fNRB_results.iloc[1,2]
df_only_usage_Meter=df_usage_results.iloc[1,2]
df_only_emission_Meter=df_only_EF_results.iloc[1,2]
df_only_emission_charcoal_Meter=df_firewood_charcoal_results.iloc[1,2]
df_only_emission_adjust_Meter=df_adjusted_results.iloc[1,2]
df_only_rebound_Meter=df_rebound_results.iloc[1,2]
df_only_adoption_Meter=df_adoption_results.iloc[1,2]
df_only_stacking_Meter=df_stacking_results.iloc[1,2]
df_all_except_aut_Meter=df_all_except_aus_results.iloc[1,2]







df_all_gs_fw=df_all_results.iloc[3,2]
df_only_fNRB_gs_fw=df_fNRB_results.iloc[3,2]
df_only_usage_gs_fw=df_usage_results.iloc[3,2]
df_only_emission_gs_fw=df_only_EF_results.iloc[3,2]
df_only_emission_charcoal_gs_fw=df_firewood_charcoal_results.iloc[3,2]
df_only_emission_adjust_gs_fw=df_adjusted_results.iloc[3,2]
df_only_rebound_gs_fw=df_rebound_results.iloc[3,2]
df_only_adoption_gs_fw=df_adoption_results.iloc[3,2]
df_only_stacking_gs_fw=df_stacking_results.iloc[3,2]
df_all_except_aut_gs_fw=df_all_except_aus_results.iloc[3,2]


df_all_gs_simple=df_all_results.iloc[4,2]
df_only_fNRB_gs_simple=df_fNRB_results.iloc[4,2]
df_only_usage_gs_simple=df_usage_results.iloc[4,2]
df_only_emission_gs_simple=df_only_EF_results.iloc[4,2]
df_only_emission_charcoal_gs_simple=df_firewood_charcoal_results.iloc[4,2]
df_only_emission_adjust_gs_simple=df_adjusted_results.iloc[4,2]
df_only_rebound_gs_simple=df_rebound_results.iloc[4,2]
df_only_adoption_gs_simple=df_adoption_results.iloc[4,2]
df_only_stacking_gs_simple=df_stacking_results.iloc[4,2]
df_all_except_aut_gs_simple=df_all_except_aus_results.iloc[4,2]




df_all_gs_charc=df_all_results.iloc[5,2]
df_only_fNRB_gs_charc=df_fNRB_results.iloc[5,2]
df_only_usage_gs_charc=df_usage_results.iloc[5,2]
df_only_emission_gs_charc=df_only_EF_results.iloc[5,2]
df_only_emission_charcoal_gs_charc=df_firewood_charcoal_results.iloc[5,2]
df_only_emission_adjust_gs_charc=df_adjusted_results.iloc[5,2]
df_only_rebound_gs_charc=df_rebound_results.iloc[5,2]
df_only_adoption_gs_charc=df_adoption_results.iloc[5,2]
df_only_stacking_gs_charc=df_stacking_results.iloc[5,2]
df_all_except_aut_gs_charc=df_all_except_aus_results.iloc[5,2]





df_all_gs_lpg=df_all_results.iloc[2,2]
df_only_fNRB_gs_lpg=df_fNRB_results.iloc[2,2]
df_only_usage_gs_lpg=df_usage_results.iloc[2,2]
df_only_emission_gs_lpg=df_only_EF_results.iloc[2,2]
df_only_emission_charcoal_gs_lpg=df_firewood_charcoal_results.iloc[2,2]
df_only_emission_adjust_gs_lpg=df_adjusted_results.iloc[2,2]
df_only_rebound_gs_lpg=df_rebound_results.iloc[2,2]
df_only_adoption_gs_lpg=df_adoption_results.iloc[2,2]
df_only_stacking_gs_lpg=df_stacking_results.iloc[2,2]
df_all_except_aut_gs_lpg=df_all_except_aus_results.iloc[2,2]



df_all_IIG_fw=df_all_results.iloc[6,2]
df_only_fNRB_IIG_fw=df_fNRB_results.iloc[6,2]
df_only_usage_IIG_fw=df_usage_results.iloc[6,2]
df_only_emission_IIG_fw=df_only_EF_results.iloc[6,2]
df_only_emission_charcoal_IIG_fw=df_firewood_charcoal_results.iloc[6,2]
df_only_emission_adjust_IIG_fw=df_adjusted_results.iloc[6,2]
df_only_rebound_IIG_fw=df_rebound_results.iloc[6,2]
df_only_adoption_IIG_fw=df_adoption_results.iloc[6,2]
df_only_stacking_IIG_fw=df_stacking_results.iloc[6,2]
df_all_except_aut_IIG_fw=df_all_except_aus_results.iloc[6,2]




df_all_IIG_charc=df_all_results.iloc[7,2]
df_only_fNRB_IIG_charc=df_fNRB_results.iloc[7,2]
df_only_usage_IIG_charc=df_usage_results.iloc[7,2]
df_only_emission_IIG_charc=df_only_EF_results.iloc[7,2]
df_only_emission_charcoal_IIG_charc=df_firewood_charcoal_results.iloc[7,2]
df_only_emission_adjust_IIG_charc=df_adjusted_results.iloc[7,2]
df_only_rebound_IIG_charc=df_rebound_results.iloc[7,2]
df_only_adoption_IIG_charc=df_adoption_results.iloc[7,2]
df_only_stacking_IIG_charc=df_stacking_results.iloc[7,2]
df_all_except_aut_IIG_charc=df_all_except_aus_results.iloc[7,2]

# %%
df_all_all_error=np.array(pd.DataFrame([df_all_all-df_all_results.iloc[0,1],df_all_results.iloc[0,3]-df_all_all]))
df_only_fNRB_all_error=np.array(pd.DataFrame([df_only_fNRB_all-df_fNRB_results.iloc[0,1],df_fNRB_results.iloc[0,3]-df_only_fNRB_all]))
df_only_usage_all_error=np.array(pd.DataFrame([df_only_usage_all-df_usage_results.iloc[0,1],df_usage_results.iloc[0,3]-df_only_usage_all]))
df_only_adoption_all_error=np.array(pd.DataFrame([df_only_adoption_all-df_adoption_results.iloc[0,1],df_adoption_results.iloc[0,3]-df_only_adoption_all]))
df_only_stacking_all_error=np.array(pd.DataFrame([df_only_stacking_all-df_stacking_results.iloc[0,1],df_stacking_results.iloc[0,3]-df_only_stacking_all]))
df_all_except_aut_all_error=np.array(pd.DataFrame([df_all_except_aut_all-df_all_except_aus_results.iloc[0,1],df_all_except_aus_results.iloc[0,3]-df_all_except_aut_all]))

df_only_rebound_all_error=np.array(pd.DataFrame([df_only_rebound_all-df_rebound_results.iloc[0,1],df_rebound_results.iloc[0,3]-df_only_rebound_all]))
df_only_emission_all_error=np.array(pd.DataFrame([df_only_emission_all-df_only_EF_results.iloc[0,1],df_only_EF_results.iloc[0,3]-df_only_emission_all]))
df_only_emission_charcoal_all_error=np.array(pd.DataFrame([df_only_emission_charcoal_all-df_firewood_charcoal_results.iloc[0,1],df_firewood_charcoal_results.iloc[0,3]-df_only_emission_charcoal_all]))
df_only_emission_adjust_all_error=np.array(pd.DataFrame([df_only_emission_adjust_all-df_adjusted_results.iloc[0,1],df_adjusted_results.iloc[0,3]-df_only_emission_adjust_all]))



df_all_IE_error=np.array(pd.DataFrame([df_all_IE-df_all_results.iloc[8,1],df_all_results.iloc[8,3]-df_all_IE]))
df_only_fNRB_IE_error=np.array(pd.DataFrame([df_only_fNRB_IE-df_fNRB_results.iloc[8,1],df_fNRB_results.iloc[8,3]-df_only_fNRB_IE]))
df_only_usage_IE_error=np.array(pd.DataFrame([df_only_usage_IE-df_usage_results.iloc[8,1],df_usage_results.iloc[8,3]-df_only_usage_IE]))
df_only_adoption_IE_error=np.array(pd.DataFrame([df_only_adoption_IE-df_adoption_results.iloc[8,1],df_adoption_results.iloc[8,3]-df_only_adoption_IE]))
df_only_stacking_IE_error=np.array(pd.DataFrame([df_only_stacking_IE-df_stacking_results.iloc[8,1],df_stacking_results.iloc[8,3]-df_only_stacking_IE]))
df_all_except_aut_IE_error=np.array(pd.DataFrame([df_all_except_aut_IE-df_all_except_aus_results.iloc[8,1],df_all_except_aus_results.iloc[8,3]-df_all_except_aut_IE]))

df_only_rebound_IE_error=np.array(pd.DataFrame([df_only_rebound_IE-df_rebound_results.iloc[8,1],df_rebound_results.iloc[8,3]-df_only_rebound_IE]))
df_only_emission_IE_error=np.array(pd.DataFrame([df_only_emission_IE-df_only_EF_results.iloc[8,1],df_only_EF_results.iloc[8,3]-df_only_emission_IE]))
df_only_emission_charcoal_IE_error=np.array(pd.DataFrame([df_only_emission_charcoal_IE-df_firewood_charcoal_results.iloc[8,1],df_firewood_charcoal_results.iloc[8,3]-df_only_emission_charcoal_IE]))
df_only_emission_adjust_IE_error=np.array(pd.DataFrame([df_only_emission_adjust_IE-df_adjusted_results.iloc[8,1],df_adjusted_results.iloc[8,3]-df_only_emission_adjust_IE]))



df_all_Meter_error=np.array(pd.DataFrame([df_all_Meter-df_all_results.iloc[1,1],df_all_results.iloc[1,3]-df_all_Meter]))
df_only_fNRB_Meter_error=np.array(pd.DataFrame([df_only_fNRB_Meter-df_fNRB_results.iloc[1,1],df_fNRB_results.iloc[1,3]-df_only_fNRB_Meter]))
df_only_usage_Meter_error=np.array(pd.DataFrame([df_only_usage_Meter-df_usage_results.iloc[1,1],df_usage_results.iloc[1,3]-df_only_usage_Meter]))
df_only_adoption_Meter_error=np.array(pd.DataFrame([df_only_adoption_Meter-df_adoption_results.iloc[1,1],df_adoption_results.iloc[1,3]-df_only_adoption_Meter]))
df_only_stacking_Meter_error=np.array(pd.DataFrame([df_only_stacking_Meter-df_stacking_results.iloc[1,1],df_stacking_results.iloc[1,3]-df_only_stacking_Meter]))
df_all_except_aut_Meter_error=np.array(pd.DataFrame([df_all_except_aut_Meter-df_all_except_aus_results.iloc[1,1],df_all_except_aus_results.iloc[1,3]-df_all_except_aut_Meter]))
df_only_rebound_Meter_error=np.array(pd.DataFrame([df_only_rebound_Meter-df_rebound_results.iloc[1,1],df_rebound_results.iloc[1,3]-df_only_rebound_Meter]))

df_only_emission_Meter_error=np.array(pd.DataFrame([df_only_emission_Meter-df_only_EF_results.iloc[8,1],df_only_EF_results.iloc[8,3]-df_only_emission_Meter]))
df_only_emission_charcoal_Meter_error=np.array(pd.DataFrame([df_only_emission_charcoal_Meter-df_firewood_charcoal_results.iloc[8,1],df_firewood_charcoal_results.iloc[8,3]-df_only_emission_charcoal_Meter]))
df_only_emission_adjust_Meter_error=np.array(pd.DataFrame([df_only_emission_adjust_Meter-df_adjusted_results.iloc[8,1],df_adjusted_results.iloc[8,3]-df_only_emission_adjust_Meter]))



df_all_gs_fw_error=np.array(pd.DataFrame([df_all_gs_fw-df_all_results.iloc[3,1],df_all_results.iloc[3,3]-df_all_gs_fw]))
df_only_fNRB_gs_fw_error=np.array(pd.DataFrame([df_only_fNRB_gs_fw-df_fNRB_results.iloc[3,1],df_fNRB_results.iloc[3,3]-df_only_fNRB_gs_fw]))
df_only_usage_gs_fw_error=np.array(pd.DataFrame([df_only_usage_gs_fw-df_usage_results.iloc[3,1],df_usage_results.iloc[3,3]-df_only_usage_gs_fw]))
df_only_adoption_gs_fw_error=np.array(pd.DataFrame([df_only_adoption_gs_fw-df_adoption_results.iloc[3,1],df_adoption_results.iloc[3,3]-df_only_adoption_gs_fw]))
df_only_stacking_gs_fw_error=np.array(pd.DataFrame([df_only_stacking_gs_fw-df_stacking_results.iloc[3,1],df_stacking_results.iloc[3,3]-df_only_stacking_gs_fw]))
df_all_except_aut_gs_fw_error=np.array(pd.DataFrame([df_all_except_aut_gs_fw-df_all_except_aus_results.iloc[3,1],df_all_except_aus_results.iloc[3,3]-df_all_except_aut_gs_fw]))
df_only_rebound_gs_fw_error=np.array(pd.DataFrame([df_only_rebound_gs_fw-df_rebound_results.iloc[3,1],df_rebound_results.iloc[3,3]-df_only_rebound_gs_fw]))

df_only_emission_gs_fw_error=np.array(pd.DataFrame([df_only_emission_gs_fw-df_only_EF_results.iloc[3,1],df_only_EF_results.iloc[3,3]-df_only_emission_gs_fw]))
df_only_emission_charcoal_gs_fw_error=np.array(pd.DataFrame([df_only_emission_charcoal_gs_fw-df_firewood_charcoal_results.iloc[3,1],df_firewood_charcoal_results.iloc[3,3]-df_only_emission_charcoal_gs_fw]))
df_only_emission_adjust_gs_fw_error=np.array(pd.DataFrame([df_only_emission_adjust_gs_fw-df_adjusted_results.iloc[3,1],df_adjusted_results.iloc[3,3]-df_only_emission_adjust_gs_fw]))



df_all_gs_lpg_error=np.array(pd.DataFrame([df_all_gs_lpg-df_all_results.iloc[2,1],df_all_results.iloc[2,3]-df_all_gs_lpg]))
df_only_fNRB_gs_lpg_error=np.array(pd.DataFrame([df_only_fNRB_gs_lpg-df_fNRB_results.iloc[2,1],df_fNRB_results.iloc[2,3]-df_only_fNRB_gs_lpg]))
df_only_usage_gs_lpg_error=np.array(pd.DataFrame([df_only_usage_gs_lpg-df_usage_results.iloc[2,1],df_usage_results.iloc[2,3]-df_only_usage_gs_lpg]))
df_only_adoption_gs_lpg_error=np.array(pd.DataFrame([df_only_adoption_gs_lpg-df_adoption_results.iloc[2,1],df_adoption_results.iloc[2,3]-df_only_adoption_gs_lpg]))
df_only_stacking_gs_lpg_error=np.array(pd.DataFrame([df_only_stacking_gs_lpg-df_stacking_results.iloc[2,1],df_stacking_results.iloc[2,3]-df_only_stacking_gs_lpg]))
df_all_except_aut_gs_lpg_error=np.array(pd.DataFrame([df_all_except_aut_gs_lpg-df_all_except_aus_results.iloc[2,1],df_all_except_aus_results.iloc[2,3]-df_all_except_aut_gs_lpg]))
df_only_rebound_gs_lpg_error=np.array(pd.DataFrame([df_only_rebound_gs_lpg-df_rebound_results.iloc[2,1],df_rebound_results.iloc[2,3]-df_only_rebound_gs_lpg]))

df_only_emission_gs_lpg_error=np.array(pd.DataFrame([df_only_emission_gs_lpg-df_only_EF_results.iloc[2,1],df_only_EF_results.iloc[2,3]-df_only_emission_gs_lpg]))
df_only_emission_charcoal_gs_lpg_error=np.array(pd.DataFrame([df_only_emission_charcoal_gs_lpg-df_firewood_charcoal_results.iloc[2,1],df_firewood_charcoal_results.iloc[2,3]-df_only_emission_charcoal_gs_lpg]))
df_only_emission_adjust_gs_lpg_error=np.array(pd.DataFrame([df_only_emission_adjust_gs_lpg-df_adjusted_results.iloc[2,1],df_adjusted_results.iloc[2,3]-df_only_emission_adjust_gs_lpg]))



df_all_IIG_fw_error=np.array(pd.DataFrame([df_all_IIG_fw-df_all_results.iloc[6,1],df_all_results.iloc[6,3]-df_all_IIG_fw]))
df_only_fNRB_IIG_fw_error=np.array(pd.DataFrame([df_only_fNRB_IIG_fw-df_fNRB_results.iloc[6,1],df_fNRB_results.iloc[6,3]-df_only_fNRB_IIG_fw]))
df_only_usage_IIG_fw_error=np.array(pd.DataFrame([df_only_usage_IIG_fw-df_usage_results.iloc[6,1],df_usage_results.iloc[6,3]-df_only_usage_IIG_fw]))
df_only_adoption_IIG_fw_error=np.array(pd.DataFrame([df_only_adoption_IIG_fw-df_adoption_results.iloc[6,1],df_adoption_results.iloc[6,3]-df_only_adoption_IIG_fw]))
df_only_stacking_IIG_fw_error=np.array(pd.DataFrame([df_only_stacking_IIG_fw-df_stacking_results.iloc[6,1],df_stacking_results.iloc[6,3]-df_only_stacking_IIG_fw]))
df_all_except_aut_IIG_fw_error=np.array(pd.DataFrame([df_all_except_aut_IIG_fw-df_all_except_aus_results.iloc[6,1],df_all_except_aus_results.iloc[6,3]-df_all_except_aut_IIG_fw]))
df_only_rebound_IIG_fw_error=np.array(pd.DataFrame([df_only_rebound_IIG_fw-df_rebound_results.iloc[6,1],df_rebound_results.iloc[6,3]-df_only_rebound_IIG_fw]))

df_only_emission_IIG_fw_error=np.array(pd.DataFrame([df_only_emission_IIG_fw-df_only_EF_results.iloc[8,1],df_only_EF_results.iloc[6,3]-df_only_emission_IIG_fw]))
df_only_emission_charcoal_IIG_fw_error=np.array(pd.DataFrame([df_only_emission_charcoal_IIG_fw-df_firewood_charcoal_results.iloc[6,1],df_firewood_charcoal_results.iloc[6,3]-df_only_emission_charcoal_IIG_fw]))
df_only_emission_adjust_IIG_fw_error=np.array(pd.DataFrame([df_only_emission_adjust_IIG_fw-df_adjusted_results.iloc[6,1],df_adjusted_results.iloc[6,3]-df_only_emission_adjust_IIG_fw]))



df_all_IIG_charc_error=np.array(pd.DataFrame([df_all_IIG_charc-df_all_results.iloc[7,1],df_all_results.iloc[7,3]-df_all_IIG_charc]))
df_only_fNRB_IIG_charc_error=np.array(pd.DataFrame([df_only_fNRB_IIG_charc-df_fNRB_results.iloc[7,1],df_fNRB_results.iloc[7,3]-df_only_fNRB_IIG_charc]))
df_only_usage_IIG_charc_error=np.array(pd.DataFrame([df_only_usage_IIG_charc-df_usage_results.iloc[7,1],df_usage_results.iloc[7,3]-df_only_usage_IIG_charc]))
df_only_adoption_IIG_charc_error=np.array(pd.DataFrame([df_only_adoption_IIG_charc-df_adoption_results.iloc[7,1],df_adoption_results.iloc[7,3]-df_only_adoption_IIG_charc]))
df_only_stacking_IIG_charc_error=np.array(pd.DataFrame([df_only_stacking_IIG_charc-df_stacking_results.iloc[7,1],df_stacking_results.iloc[7,3]-df_only_stacking_IIG_charc]))
df_all_except_aut_IIG_charc_error=np.array(pd.DataFrame([df_all_except_aut_IIG_charc-df_all_except_aus_results.iloc[7,1],df_all_except_aus_results.iloc[7,3]-df_all_except_aut_IIG_charc]))
df_only_rebound_IIG_charc_error=np.array(pd.DataFrame([df_only_rebound_IIG_charc-df_rebound_results.iloc[7,1],df_rebound_results.iloc[7,3]-df_only_rebound_IIG_charc]))

df_only_emission_IIG_charc_error=np.array(pd.DataFrame([df_only_emission_IIG_charc-df_only_EF_results.iloc[7,1],df_only_EF_results.iloc[7,3]-df_only_emission_IIG_charc]))
df_only_emission_charcoal_IIG_charc_error=np.array(pd.DataFrame([df_only_emission_charcoal_IIG_charc-df_firewood_charcoal_results.iloc[7,1],df_firewood_charcoal_results.iloc[7,3]-df_only_emission_charcoal_IIG_charc]))
df_only_emission_adjust_IIG_charc_error=np.array(pd.DataFrame([df_only_emission_adjust_IIG_charc-df_adjusted_results.iloc[7,1],df_adjusted_results.iloc[7,3]-df_only_emission_adjust_IIG_charc]))



df_all_gs_simple_error=np.array(pd.DataFrame([df_all_gs_simple-df_all_results.iloc[4,1],df_all_results.iloc[4,3]-df_all_gs_simple]))
df_only_fNRB_gs_simple_error=np.array(pd.DataFrame([df_only_fNRB_gs_simple-df_fNRB_results.iloc[4,1],df_fNRB_results.iloc[4,3]-df_only_fNRB_gs_simple]))
df_only_usage_gs_simple_error=np.array(pd.DataFrame([df_only_usage_gs_simple-df_usage_results.iloc[4,1],df_usage_results.iloc[4,3]-df_only_usage_gs_simple]))
df_only_adoption_gs_simple_error=np.array(pd.DataFrame([df_only_adoption_gs_simple-df_adoption_results.iloc[4,1],df_adoption_results.iloc[4,3]-df_only_adoption_gs_simple]))
df_only_stacking_gs_simple_error=np.array(pd.DataFrame([df_only_stacking_gs_simple-df_stacking_results.iloc[4,1],df_stacking_results.iloc[4,3]-df_only_stacking_gs_simple]))
df_all_except_aut_gs_simple_error=np.array(pd.DataFrame([df_all_except_aut_gs_simple-df_all_except_aus_results.iloc[4,1],df_all_except_aus_results.iloc[4,3]-df_all_except_aut_gs_simple]))
df_only_rebound_gs_simple_error=np.array(pd.DataFrame([df_only_rebound_gs_simple-df_rebound_results.iloc[4,1],df_rebound_results.iloc[4,3]-df_only_rebound_gs_simple]))

df_only_emission_gs_simple_error=np.array(pd.DataFrame([df_only_emission_gs_simple-df_only_EF_results.iloc[4,1],df_only_EF_results.iloc[4,3]-df_only_emission_gs_simple]))
df_only_emission_charcoal_gs_simple_error=np.array(pd.DataFrame([df_only_emission_charcoal_gs_simple-df_firewood_charcoal_results.iloc[4,1],df_firewood_charcoal_results.iloc[4,3]-df_only_emission_charcoal_gs_simple]))
df_only_emission_adjust_gs_simple_error=np.array(pd.DataFrame([df_only_emission_adjust_gs_simple-df_adjusted_results.iloc[4,1],df_adjusted_results.iloc[4,3]-df_only_emission_adjust_gs_simple]))




df_all_gs_charc_error=np.array(pd.DataFrame([df_all_gs_charc-df_all_results.iloc[5,1],df_all_results.iloc[5,3]-df_all_gs_charc]))
df_only_fNRB_gs_charc_error=np.array(pd.DataFrame([df_only_fNRB_gs_charc-df_fNRB_results.iloc[5,1],df_fNRB_results.iloc[5,3]-df_only_fNRB_gs_charc]))
df_only_usage_gs_charc_error=np.array(pd.DataFrame([df_only_usage_gs_charc-df_usage_results.iloc[5,1],df_usage_results.iloc[5,3]-df_only_usage_gs_charc]))
df_only_adoption_gs_charc_error=np.array(pd.DataFrame([df_only_adoption_gs_charc-df_adoption_results.iloc[5,1],df_adoption_results.iloc[5,3]-df_only_adoption_gs_charc]))
df_only_stacking_gs_charc_error=np.array(pd.DataFrame([df_only_stacking_gs_charc-df_stacking_results.iloc[5,1],df_stacking_results.iloc[5,3]-df_only_stacking_gs_charc]))
df_all_except_aut_gs_charc_error=np.array(pd.DataFrame([df_all_except_aut_gs_charc-df_all_except_aus_results.iloc[5,1],df_all_except_aus_results.iloc[5,3]-df_all_except_aut_gs_charc]))
df_only_rebound_gs_charc_error=np.array(pd.DataFrame([df_only_rebound_gs_charc-df_rebound_results.iloc[5,1],df_rebound_results.iloc[5,3]-df_only_rebound_gs_charc]))

                                                               
df_only_emission_gs_charc_error=np.array(pd.DataFrame([df_only_emission_gs_charc-df_only_EF_results.iloc[5,1],df_only_EF_results.iloc[5,3]-df_only_emission_gs_charc]))
df_only_emission_charcoal_gs_charc_error=np.array(pd.DataFrame([df_only_emission_charcoal_gs_charc-df_firewood_charcoal_results.iloc[5,1],df_firewood_charcoal_results.iloc[5,3]-df_only_emission_charcoal_gs_charc]))
df_only_emission_adjust_gs_charc_error=np.array(pd.DataFrame([df_only_emission_adjust_gs_charc-df_adjusted_results.iloc[5,1],df_adjusted_results.iloc[5,3]-df_only_emission_adjust_gs_charc]))

# %%
f=lambda a: (abs(a)+a)/2

# %%
fig = plt.figure(figsize =(7.08, 8.26))

plt.subplots_adjust(wspace=0.25, hspace=0.3)

ax10=fig.add_subplot(6,2,(1,3))
ax10.axhline(y=1, xmin=0, xmax=9, color="yellow", label='Neutral crediting')
ax10.axhspan(0, 1, facecolor='green', alpha=0.1, label='Under-crediting')
ax10.axhspan(1, 80, facecolor='red', alpha=0.1, label='Over-crediting')
ax10.errorbar(x_all, df_all_all, yerr=df_all_all_error,marker='D',ms=3,label='All',mec='#DC0000FF',mfc='#DC0000FF',ecolor='#DC0000FF',barsabove=True, capsize=7,fmt='o')
ax10.errorbar(x_gs_fw, df_all_gs_fw, yerr=pd.DataFrame({'col1': [df_all_gs_fw-.1, np.int(df_all_gs_fw_error[1])]}),marker='.',ms=5, label='GS-Firewood',mec='#00A087FF',mfc='#00A087FF',ecolor='#00A087FF',barsabove=True, capsize=7,fmt='o')
ax10.errorbar(x_gs_simple_fw, df_all_gs_simple, yerr=df_all_gs_simple_error,marker='.',ms=5, label='GS-Simplified Firewood',mec='#B09C85FF',mfc='#B09C85FF',ecolor='#B09C85FF',barsabove=True, capsize=7,fmt='o')

ax10.errorbar(x_IIG_fw, df_all_IIG_fw, yerr=pd.DataFrame({'col1': [df_all_IIG_fw-.1, np.int(df_all_IIG_fw_error[1])]}),marker='.',ms=5, label="CDM AMS II G-Firewood",mec='#8491B4FF',mfc='#8491B4FF',ecolor='#8491B4FF',barsabove=True, capsize=7,fmt='o')
ax10.errorbar(x_gs_charc, df_all_gs_charc, yerr=df_all_gs_charc_error,marker='.',ms=5,label="GS-Charcoal",mec='#3C5488FF',mfc='#3C5488FF',ecolor='#3C5488FF',barsabove=True, capsize=7,fmt='o')
ax10.errorbar(x_IIG_charc, df_all_IIG_charc, yerr=df_all_IIG_charc_error,marker='.',ms=5,label="CDM AMS II G-Charcoal",mec='#7E6148FF', mfc='#7E6148FF',ecolor='#7E6148FF',barsabove=True, capsize=7,fmt='o')
ax10.errorbar(x_gs_lpg, df_all_gs_lpg, yerr=pd.DataFrame({'col1': [df_all_gs_lpg-.1, np.int(df_all_gs_lpg_error[1])]}),marker='*',ms=5,label="GS-LPG",mec='#4DBBD5FF',mfc='#4DBBD5FF',ecolor='#4DBBD5FF',barsabove=True, capsize=7,fmt='o')
ax10.errorbar(x_IE, df_all_IE, yerr=df_all_IE_error,marker='*',ms=5,label="AMS I E-Ethanol",mec='#F39B7FFF',mfc='#F39B7FFF',ecolor='#F39B7FFF',barsabove=True, capsize=7,fmt='o')
ax10.errorbar(x_Meter, df_all_Meter, yerr=df_all_Meter_error,marker='*',ms=5, label="GS Metered-Pellets",mec='#91D1C2FF',mfc='#91D1C2FF',ecolor='#91D1C2FF',barsabove=True, capsize=7,fmt='o')
ax10.set_ylabel('Times over-credited',size=7)
ax10.set_ylim(-1,60)
ax10.tick_params(axis='x',color='w',labelcolor='w')
ax10.tick_params(axis='y',labelsize=7)


ax10.set_title('(a) All factors',size=7,loc='left')

ax1=fig.add_subplot(6,2,11)

ax1.tick_params(axis='x',color='w',labelcolor='w')
ax1.axhspan(0, 1, facecolor='green', alpha=0.1)
ax1.axhspan(1, 7, facecolor='red', alpha=0.1) 
ax1.axhline(y=1, xmin=0, xmax=9, color="yellow", label='Neutral crediting')
             
ax1.errorbar(x_all, df_only_fNRB_all, yerr=df_only_fNRB_all_error,marker='D',ms=3,label='All',mec='#DC0000FF',mfc='#DC0000FF',ecolor='#DC0000FF',barsabove=True, capsize=7,fmt='o')
ax1.errorbar(x_gs_fw, df_only_fNRB_gs_fw, yerr=pd.DataFrame({'col1': [df_only_fNRB_gs_fw, np.int(df_only_fNRB_gs_fw_error[1])]}),marker='.',ms=5, label='GS - Imp. Firewood',mec='#00A087FF',mfc='#00A087FF',ecolor='#00A087FF',barsabove=True, capsize=7,fmt='o')
ax1.errorbar(x_gs_simple_fw, df_only_fNRB_gs_simple, yerr=df_only_fNRB_gs_simple_error,marker='.',ms=5, label='GS -Simplified Firewood',mec='#B09C85FF',mfc='#B09C85FF',ecolor='#B09C85FF',barsabove=True, capsize=7,fmt='o')
ax1.errorbar(x_IIG_fw, df_only_fNRB_IIG_fw, yerr=df_only_fNRB_IIG_fw_error,marker='.',ms=5, label="AMS II G - Imp. Firewood",mec='#8491B4FF',mfc='#8491B4FF',ecolor='#8491B4FF',barsabove=True, capsize=7,fmt='o')
ax1.errorbar(x_gs_charc, df_only_fNRB_gs_charc, yerr=df_only_fNRB_gs_charc_error,marker='.',ms=5,label="GS - Imp. Charcoal",mec='#3C5488FF',mfc='#3C5488FF',ecolor='#3C5488FF',barsabove=True, capsize=7,fmt='o')
ax1.errorbar(x_IIG_charc, df_only_fNRB_IIG_charc, yerr=df_only_fNRB_IIG_charc_error,marker='.',ms=5,label="AMS II G - Imp. Charcoal",mec='#7E6148FF', mfc='#7E6148FF',ecolor='#7E6148FF',barsabove=True, capsize=7,fmt='o')
ax1.errorbar(x_gs_lpg, df_only_fNRB_gs_lpg, yerr=pd.DataFrame({'col1': [df_only_fNRB_gs_lpg, np.int(df_only_fNRB_gs_lpg_error[1])]}),marker='*',ms=5,label="GS - LPG",mec='#4DBBD5FF',mfc='#4DBBD5FF',ecolor='#4DBBD5FF',barsabove=True, capsize=7,fmt='o')
ax1.errorbar(x_IE, df_only_fNRB_IE, yerr=df_only_fNRB_IE_error,marker='*',ms=5,label="AMS I E - Ethanol",mec='#F39B7FFF',mfc='#F39B7FFF',ecolor='#F39B7FFF',barsabove=True, capsize=7,fmt='o')
ax1.errorbar(x_Meter, df_only_fNRB_Meter, yerr=df_only_fNRB_Meter_error,marker='*',ms=5, label="GS Metered - Pellets",mec='#91D1C2FF',mfc='#91D1C2FF',ecolor='#91D1C2FF',barsabove=True, capsize=7,fmt='o')
ax1.tick_params(axis='y',labelsize=7)
ax1.set_ylim(-.1,5.25)
ax1.tick_params(axis='x',color='w',labelcolor='w')
ax1.set_xlabel('Methodology-stove combination', size=7)
            
      

ax1.set_ylabel('Times over-credited',size=7)
ax1.set_title('(e) Only fNRB',size=7,loc='left')




ax2=fig.add_subplot(6,2,7)
ax2.axhspan(0, 1, facecolor='green', alpha=0.1)
ax2.axhspan(1, 7, facecolor='red', alpha=0.1) 
ax2.axhline(y=1, xmin=0, xmax=9, color="yellow", label='Neutral crediting')          
  
ax2.errorbar(x_all, df_only_usage_all, yerr=df_only_usage_all_error,marker='D',ms=3,label='All',mec='#DC0000FF',mfc='#DC0000FF',ecolor='#DC0000FF',barsabove=True, capsize=7,fmt='o')
ax2.errorbar(x_gs_fw, df_only_usage_gs_fw, yerr=df_only_usage_gs_fw_error,marker='.',ms=5, label='GS - Imp. Firewood',mec='#00A087FF',mfc='#00A087FF',ecolor='#00A087FF',barsabove=True, capsize=7,fmt='o')
ax2.errorbar(x_gs_simple_fw, df_only_usage_gs_simple, yerr=df_only_usage_gs_simple_error,marker='.',ms=5, label='GS - Simplified Firewood',mec='#B09C85FF',mfc='#B09C85FF',ecolor='#B09C85FF',barsabove=True, capsize=7,fmt='o')

ax2.errorbar(x_IIG_fw, df_only_usage_IIG_fw, yerr=df_only_usage_IIG_fw_error,marker='.',ms=5, label="AMS II G - Imp. Firewood",mec='#8491B4FF',mfc='#8491B4FF',ecolor='#8491B4FF',barsabove=True, capsize=7,fmt='o')
ax2.errorbar(x_gs_charc, df_only_usage_gs_charc, yerr=df_only_usage_gs_charc_error,marker='.',ms=5,label="GS - Imp. Charcoal",mec='#3C5488FF',mfc='#3C5488FF',ecolor='#3C5488FF',barsabove=True, capsize=7,fmt='o')
ax2.errorbar(x_IIG_charc, df_only_usage_IIG_charc, yerr=df_only_usage_IIG_charc_error,marker='.',ms=5,label="AMS II G - Imp. Charcoal",mec='#7E6148FF', mfc='#7E6148FF',ecolor='#7E6148FF',barsabove=True, capsize=7,fmt='o')
ax2.errorbar(x_gs_lpg, df_only_usage_gs_lpg, yerr=df_only_usage_gs_lpg_error,marker='*',ms=5,label="GS - LPG",mec='#4DBBD5FF',mfc='#4DBBD5FF',ecolor='#4DBBD5FF',barsabove=True, capsize=7,fmt='o')
ax2.errorbar(x_IE, df_only_usage_IE, yerr=df_only_usage_IE_error,marker='*',ms=5,label="AMS I E - Ethanol",mec='#F39B7FFF',mfc='#F39B7FFF',ecolor='#F39B7FFF',barsabove=True, capsize=7,fmt='o')
ax2.errorbar(x_Meter, df_only_usage_Meter, yerr=df_only_usage_Meter_error,marker='*',ms=5, label="GS Metered - Pellets",mec='#91D1C2FF',mfc='#91D1C2FF',ecolor='#91D1C2FF',barsabove=True, capsize=7,fmt='o')
ax2.tick_params(axis='y',labelsize=7)

ax2.set_ylabel('Times over-credited',size=7)
ax2.set_title('(c) Only usage rates',size=7,loc='left')
ax2.set_ylim(-.1,5.25)
ax2.tick_params(axis='x',color='w',labelcolor='w')
 


ax3=fig.add_subplot(6,2,2)
ax3.axhspan(0, 1, facecolor='green', alpha=0.1)
ax3.axhspan(1, 7, facecolor='red', alpha=0.1) 
ax3.axhline(y=1, xmin=0, xmax=9, color="yellow", label='Neutral crediting')
     
ax3.tick_params(axis='y',labelsize=7)
ax3.errorbar(x_all, df_only_emission_all, yerr=df_only_emission_all_error,marker='D',ms=3,label='All',mec='#DC0000FF',mfc='#DC0000FF',ecolor='#DC0000FF',barsabove=True, capsize=7,fmt='o')
ax3.errorbar(x_gs_fw, df_only_emission_gs_fw, yerr=df_only_emission_gs_fw_error,marker='.',ms=5, label='GS - Imp. Firewood',mec='#00A087FF',mfc='#00A087FF',ecolor='#00A087FF',barsabove=True, capsize=7,fmt='o')
ax3.errorbar(x_gs_simple_fw, df_only_emission_gs_simple, yerr=df_only_emission_gs_simple_error,marker='.',ms=5, label='GS - Simplified Firewood',mec='#B09C85FF',mfc='#B09C85FF',ecolor='#B09C85FF',barsabove=True, capsize=7,fmt='o')

ax3.errorbar(x_IIG_fw, df_only_emission_IIG_fw, yerr=df_only_emission_IIG_fw_error,marker='.',ms=5, label="AMS II G - Imp. Firewood",mec='#8491B4FF',mfc='#8491B4FF',ecolor='#8491B4FF',barsabove=True, capsize=7,fmt='o')
ax3.errorbar(x_gs_charc, df_only_emission_gs_charc, yerr=pd.DataFrame({'col1': [df_only_emission_gs_charc, 0.6]}),marker='.',ms=5,label="GS - Imp. Charcoal",mec='#3C5488FF',mfc='#3C5488FF',ecolor='#3C5488FF',barsabove=True, capsize=7,fmt='o')
ax3.errorbar(x_IIG_charc, df_only_emission_IIG_charc, yerr=df_only_emission_IIG_charc_error,marker='.',ms=5,label="AMS II G - Imp. Charcoal",mec='#7E6148FF', mfc='#7E6148FF',ecolor='#7E6148FF',barsabove=True, capsize=7,fmt='o')
ax3.errorbar(x_gs_lpg, df_only_emission_gs_lpg, yerr=df_only_emission_gs_lpg_error,marker='*',ms=5,label="GS - LPG",mec='#4DBBD5FF',mfc='#4DBBD5FF',ecolor='#4DBBD5FF',barsabove=True, capsize=7,fmt='o')
ax3.errorbar(x_IE, df_only_emission_IE, yerr=df_only_emission_IE_error,marker='*',ms=5,label="AMS I E - Ethanol",mec='#F39B7FFF',mfc='#F39B7FFF',ecolor='#F39B7FFF',barsabove=True, capsize=7,fmt='o')
ax3.errorbar(x_Meter, df_only_emission_Meter, yerr=df_only_emission_Meter_error,marker='*',ms=5, label="GS Metered - Pellets",mec='#91D1C2FF',mfc='#91D1C2FF',ecolor='#91D1C2FF',barsabove=True, capsize=7,fmt='o')


ax3.set_title('(f) Only emission factors',size=7,loc='left')
ax3.set_ylim(-0.1,5.25)
ax3.tick_params(axis='x',color='w',labelcolor='w')
 


ax4=fig.add_subplot(6,2,4)
ax4.axhspan(0, 1, facecolor='green', alpha=0.1)
ax4.axhspan(1, 7, facecolor='red', alpha=0.1) 
ax4.axhline(y=1, xmin=0, xmax=9, color="yellow", label='Neutral crediting')
    
ax4.errorbar(x_all, df_only_emission_charcoal_all, yerr=df_only_emission_charcoal_all_error,marker='D',ms=3,label='All',mec='#DC0000FF',mfc='#DC0000FF',ecolor='#DC0000FF',barsabove=True, capsize=7,fmt='o')
ax4.errorbar(x_gs_fw, df_only_emission_charcoal_gs_fw, yerr=df_only_emission_charcoal_gs_fw_error,marker='.',ms=5, label='GS - Imp. Firewood',mec='#00A087FF',mfc='#00A087FF',ecolor='#00A087FF',barsabove=True, capsize=7,fmt='o')
ax4.errorbar(x_gs_simple_fw, df_only_emission_charcoal_gs_simple, yerr=df_only_emission_charcoal_gs_simple_error,marker='.',ms=5, label='GS - Simplified Firewood',mec='#B09C85FF',mfc='#B09C85FF',ecolor='#B09C85FF',barsabove=True, capsize=7,fmt='o')

ax4.errorbar(x_IIG_fw, df_only_emission_charcoal_IIG_fw, yerr=df_only_emission_charcoal_IIG_fw_error,marker='.',ms=5, label="AMS II G - Imp. Firewood",mec='#8491B4FF',mfc='#8491B4FF',ecolor='#8491B4FF',barsabove=True, capsize=7,fmt='o')
ax4.errorbar(x_gs_charc, df_only_emission_charcoal_gs_charc, yerr=pd.DataFrame({'col1': [df_only_emission_charcoal_gs_charc,np.int(df_only_emission_charcoal_gs_charc_error[1])]}),marker='.',ms=5,label="GS - Imp. Charcoal",mec='#3C5488FF',mfc='#3C5488FF',ecolor='#3C5488FF',barsabove=True, capsize=7,fmt='o')
ax4.errorbar(x_IIG_charc, df_only_emission_charcoal_IIG_charc, yerr=df_only_emission_charcoal_IIG_charc_error,marker='.',ms=5,label="AMS II G - Imp. Charcoal",mec='#7E6148FF', mfc='#7E6148FF',ecolor='#7E6148FF',barsabove=True, capsize=7,fmt='o')
ax4.errorbar(x_gs_lpg, df_only_emission_charcoal_gs_lpg, yerr=df_only_emission_charcoal_gs_lpg_error,marker='*',ms=5,label="GS - LPG",mec='#4DBBD5FF',mfc='#4DBBD5FF',ecolor='#4DBBD5FF',barsabove=True, capsize=7,fmt='o')
ax4.errorbar(x_IE, df_only_emission_charcoal_IE, yerr=df_only_emission_charcoal_IE_error,marker='*',ms=5,label="AMS I E - Ethanol",mec='#F39B7FFF',mfc='#F39B7FFF',ecolor='#F39B7FFF',barsabove=True, capsize=7,fmt='o')
ax4.errorbar(x_Meter, df_only_emission_charcoal_Meter, yerr=df_only_emission_charcoal_Meter_error,marker='*',ms=5, label="GS Metered - Pellets",mec='#91D1C2FF',mfc='#91D1C2FF',ecolor='#91D1C2FF',barsabove=True, capsize=7,fmt='o')
ax4.tick_params(axis='y',labelsize=7)
           
ax4.set_title('(g) Only firewood-charcoal conversion',size=7,loc='left')
ax4.set_ylim(-0.1,5.25)
ax4.tick_params(axis='x',color='w',labelcolor='w')



ax5=fig.add_subplot(6,2,6)
ax5.axhspan(0, 1, facecolor='green', alpha=0.1)
ax5.axhspan(1, 7, facecolor='red', alpha=0.1) 
ax5.axhline(y=1, xmin=0, xmax=9, color="yellow", label='Neutral crediting')
ax5.errorbar(x_all, df_only_emission_adjust_all, yerr=df_only_emission_adjust_all_error,marker='D',ms=3,label='All',mec='#DC0000FF',mfc='#DC0000FF',ecolor='#DC0000FF',barsabove=True, capsize=7,fmt='o')
ax5.errorbar(x_gs_fw, df_only_emission_adjust_gs_fw, yerr=df_only_emission_adjust_gs_fw_error,marker='.',ms=5, label='GS - Imp. Firewood',mec='#00A087FF',mfc='#00A087FF',ecolor='#00A087FF',barsabove=True, capsize=7,fmt='o')
ax5.errorbar(x_gs_simple_fw, df_only_emission_adjust_gs_simple, yerr=df_only_emission_adjust_gs_simple_error,marker='.',ms=5, label='GS - Simplified Firewood',mec='#B09C85FF',mfc='#B09C85FF',ecolor='#B09C85FF',barsabove=True, capsize=7,fmt='o')

ax5.errorbar(x_IIG_fw, df_only_emission_adjust_IIG_fw, yerr=df_only_emission_adjust_IIG_fw_error,marker='.',ms=5, label="AMS II G - Imp. Firewood",mec='#8491B4FF',mfc='#8491B4FF',ecolor='#8491B4FF',barsabove=True, capsize=7,fmt='o')
ax5.errorbar(x_gs_charc, df_only_emission_adjust_gs_charc, yerr=df_only_emission_adjust_gs_charc_error,marker='.',ms=5,label="GS - Imp. Charcoal",mec='#3C5488FF',mfc='#3C5488FF',ecolor='#3C5488FF',barsabove=True, capsize=7,fmt='o')
ax5.errorbar(x_IIG_charc, df_only_emission_adjust_IIG_charc, yerr=df_only_emission_adjust_IIG_charc_error,marker='.',ms=5,label="AMS II G - Imp. Charcoal",mec='#7E6148FF', mfc='#7E6148FF',ecolor='#7E6148FF',barsabove=True, capsize=7,fmt='o')
ax5.errorbar(x_gs_lpg, df_only_emission_adjust_gs_lpg, yerr=df_only_emission_adjust_gs_lpg_error,marker='*',ms=5,label="GS - LPG",mec='#4DBBD5FF',mfc='#4DBBD5FF',ecolor='#4DBBD5FF',barsabove=True, capsize=7,fmt='o')
ax5.errorbar(x_IE, df_only_emission_adjust_IE, yerr=df_only_emission_adjust_IE_error,marker='*',ms=5,label="AMS I E - Ethanol",mec='#F39B7FFF',mfc='#F39B7FFF',ecolor='#F39B7FFF',barsabove=True, capsize=7,fmt='o')
ax5.errorbar(x_Meter, df_only_emission_adjust_Meter, yerr=df_only_emission_adjust_Meter_error,marker='*',ms=5, label="GS Metered - Pellets",mec='#91D1C2FF',mfc='#91D1C2FF',ecolor='#91D1C2FF',barsabove=True, capsize=7,fmt='o')

ax5.tick_params(axis='y',labelsize=7)
               
ax5.set_title('(h) Only consumption',size=7,loc='left')
ax5.set_ylim(-.1,5.25)
ax5.tick_params(axis='x',color='w',labelcolor='w')



ax6=fig.add_subplot(6,2,8)

ax6.tick_params(axis='x',color='w',labelcolor='w')
ax6.axhline(y=1, xmin=0, xmax=9, color="yellow", label='Accurate crediting')
ax6.errorbar(x_all, df_only_rebound_all, yerr=df_only_rebound_all_error,marker='D',ms=3,label='All',mec='#DC0000FF',mfc='#DC0000FF',ecolor='#DC0000FF',barsabove=True, capsize=7,fmt='o')
ax6.errorbar(x_gs_fw, df_only_rebound_gs_fw, yerr=df_only_rebound_gs_fw_error,marker='.',ms=5, label='GS - Imp. Firewood',mec='#00A087FF',mfc='#00A087FF',ecolor='#00A087FF',barsabove=True, capsize=7,fmt='o')
ax6.errorbar(x_gs_simple_fw, df_only_rebound_gs_simple, yerr=df_only_rebound_gs_simple_error,marker='.',ms=5, label='GS - Simplified Firewood',mec='#B09C85FF',mfc='#B09C85FF',ecolor='#B09C85FF',barsabove=True, capsize=7,fmt='o')

ax6.errorbar(x_IIG_fw, df_only_rebound_IIG_fw, yerr=df_only_rebound_IIG_fw_error,marker='.',ms=5, label="AMS II G - Imp. Firewood",mec='#8491B4FF',mfc='#8491B4FF',ecolor='#8491B4FF',barsabove=True, capsize=7,fmt='o')
ax6.errorbar(x_gs_charc, df_only_rebound_gs_charc, yerr=df_only_rebound_gs_charc_error,marker='.',ms=5,label="GS - Imp. Charcoal",mec='#3C5488FF',mfc='#3C5488FF',ecolor='#3C5488FF',barsabove=True, capsize=7,fmt='o')
ax6.errorbar(x_IIG_charc, df_only_rebound_IIG_charc, yerr=df_only_rebound_IIG_charc_error,marker='.',ms=5,label="AMS II G - Imp. Charcoal",mec='#7E6148FF', mfc='#7E6148FF',ecolor='#7E6148FF',barsabove=True, capsize=7,fmt='o')
ax6.errorbar(x_gs_lpg, df_only_rebound_gs_lpg, yerr=df_only_rebound_gs_lpg_error,marker='*',ms=5,label="GS - LPG",mec='#4DBBD5FF',mfc='#4DBBD5FF',ecolor='#4DBBD5FF',barsabove=True, capsize=7,fmt='o')
ax6.errorbar(x_IE, df_only_rebound_IE, yerr=df_only_rebound_IE_error,marker='*',ms=5,label="AMS I E - Ethanol",mec='#F39B7FFF',mfc='#F39B7FFF',ecolor='#F39B7FFF',barsabove=True, capsize=7,fmt='o')
ax6.errorbar(x_Meter, df_only_rebound_Meter, yerr=df_only_rebound_Meter_error,marker='*',ms=5, label="GS Metered - Pellets",mec='#91D1C2FF',mfc='#91D1C2FF',ecolor='#91D1C2FF',barsabove=True, capsize=7,fmt='o')

ax6.axhspan(0, 1, facecolor='green', alpha=0.1, label='Under-crediting')
ax6.axhspan(1, 7, facecolor='red', alpha=0.1, label='Over-crediting') 


ax6.tick_params(axis='y',labelsize=7)
ax6.tick_params(axis='x',color='w',labelcolor='w')
ax6.set_title(' (i) Only rebound',size=7,loc='left')
ax6.set_ylim(-.1,5.25)
ax6.legend(bbox_to_anchor=(0.05,-0.25), loc='upper center',ncol=1, mode="expand", borderaxespad=0, fontsize=9)


ax7=fig.add_subplot(6,2,5)
ax7.axhspan(0, 1, facecolor='green', alpha=0.1)
ax7.axhspan(1, 7, facecolor='red', alpha=0.1) 
ax7.axhline(y=1, xmin=0, xmax=9, color="yellow", label='Neutral crediting')          
 
ax7.errorbar(x_all, df_only_adoption_all, yerr=df_only_adoption_all_error,marker='D',ms=3,label='All',mec='#DC0000FF',mfc='#DC0000FF',ecolor='#DC0000FF',barsabove=True, capsize=7,fmt='o')
ax7.errorbar(x_gs_fw, df_only_adoption_gs_fw, yerr=df_only_adoption_gs_fw_error,marker='.',ms=5, label='GS - Imp. Firewood',mec='#00A087FF',mfc='#00A087FF',ecolor='#00A087FF',barsabove=True, capsize=7,fmt='o')
ax7.errorbar(x_gs_simple_fw, df_only_adoption_gs_simple, yerr=df_only_adoption_gs_simple_error,marker='.',ms=5, label='GS - Simplified Firewood',mec='#B09C85FF',mfc='#B09C85FF',ecolor='#B09C85FF',barsabove=True, capsize=7,fmt='o')

ax7.errorbar(x_IIG_fw, df_only_adoption_IIG_fw, yerr=df_only_adoption_IIG_fw_error,marker='.',ms=5, label="AMS II G - Imp. Firewood",mec='#8491B4FF',mfc='#8491B4FF',ecolor='#8491B4FF',barsabove=True, capsize=7,fmt='o')
ax7.errorbar(x_gs_charc, df_only_adoption_gs_charc, yerr=df_only_adoption_gs_charc_error,marker='.',ms=5,label="GS - Imp. Charcoal",mec='#3C5488FF',mfc='#3C5488FF',ecolor='#3C5488FF',barsabove=True, capsize=7,fmt='o')
ax7.errorbar(x_IIG_charc, df_only_adoption_IIG_charc, yerr=df_only_adoption_IIG_charc_error,marker='.',ms=5,label="AMS II G - Imp. Charcoal",mec='#7E6148FF', mfc='#7E6148FF',ecolor='#7E6148FF',barsabove=True, capsize=7,fmt='o')
ax7.errorbar(x_gs_lpg, df_only_adoption_gs_lpg, yerr=df_only_adoption_gs_lpg_error,marker='*',ms=5,label="GS - LPG",mec='#4DBBD5FF',mfc='#4DBBD5FF',ecolor='#4DBBD5FF',barsabove=True, capsize=7,fmt='o')
ax7.errorbar(x_IE, df_only_adoption_IE, yerr=df_only_adoption_IE_error,marker='*',ms=5,label="AMS I E - Ethanol",mec='#F39B7FFF',mfc='#F39B7FFF',ecolor='#F39B7FFF',barsabove=True, capsize=7,fmt='o')
ax7.errorbar(x_Meter, df_only_adoption_Meter, yerr=df_only_adoption_Meter_error,marker='*',ms=5, label="GS Metered - Pellets",mec='#91D1C2FF',mfc='#91D1C2FF',ecolor='#91D1C2FF',barsabove=True, capsize=7,fmt='o')
ax7.tick_params(axis='y',labelsize=7)
ax7.set_title('(b) Only adoption',size=7,loc='left')
ax7.set_ylim(-.1,5.25)
ax7.set_ylabel('Times over-credited',size=7)
ax7.tick_params(axis='x',color='w',labelcolor='w')

ax8=fig.add_subplot(6,2,9)
ax8.axhspan(0, 1, facecolor='green', alpha=0.1)
ax8.axhspan(1, 7, facecolor='red', alpha=0.1) 
ax8.axhline(y=1, xmin=0, xmax=9, color="yellow", label='Neutral crediting')          

ax8.errorbar(x_all, df_only_stacking_all, yerr=df_only_stacking_all_error,marker='D',ms=3,label='All',mec='#DC0000FF',mfc='#DC0000FF',ecolor='#DC0000FF',barsabove=True, capsize=7,fmt='o')
ax8.errorbar(x_gs_fw, df_only_stacking_gs_fw, yerr=df_only_stacking_gs_fw_error,marker='.',ms=5, label='GS - Imp. Firewood',mec='#00A087FF',mfc='#00A087FF',ecolor='#00A087FF',barsabove=True, capsize=7,fmt='o')
ax8.errorbar(x_gs_simple_fw, df_only_stacking_gs_simple, yerr=df_only_stacking_gs_simple_error,marker='.',ms=5, label='GS - Simplified Firewood',mec='#B09C85FF',mfc='#B09C85FF',ecolor='#B09C85FF',barsabove=True, capsize=7,fmt='o')

ax8.errorbar(x_IIG_fw, df_only_stacking_IIG_fw, yerr=df_only_stacking_IIG_fw_error,marker='.',ms=5, label="AMS II G - Imp. Firewood",mec='#8491B4FF',mfc='#8491B4FF',ecolor='#8491B4FF',barsabove=True, capsize=7,fmt='o')
ax8.errorbar(x_gs_charc, df_only_stacking_gs_charc, yerr=df_only_stacking_gs_charc_error,marker='.',ms=5,label="GS - Imp. Charcoal",mec='#3C5488FF',mfc='#3C5488FF',ecolor='#3C5488FF',barsabove=True, capsize=7,fmt='o')
ax8.errorbar(x_IIG_charc, df_only_stacking_IIG_charc, yerr=df_only_stacking_IIG_charc_error,marker='.',ms=5,label="AMS II G - Imp. Charcoal",mec='#7E6148FF', mfc='#7E6148FF',ecolor='#7E6148FF',barsabove=True, capsize=7,fmt='o')
ax8.errorbar(x_gs_lpg, df_only_stacking_gs_lpg, yerr=df_only_stacking_gs_lpg_error,marker='*',ms=5,label="GS - LPG",mec='#4DBBD5FF',mfc='#4DBBD5FF',ecolor='#4DBBD5FF',barsabove=True, capsize=7,fmt='o')
ax8.errorbar(x_IE, df_only_stacking_IE, yerr=df_only_stacking_IE_error,marker='*',ms=5,label="AMS I E - Ethanol",mec='#F39B7FFF',mfc='#F39B7FFF',ecolor='#F39B7FFF',barsabove=True, capsize=7,fmt='o')
ax8.errorbar(x_Meter, df_only_stacking_Meter, yerr=df_only_stacking_Meter_error,marker='*',ms=5, label="GS Metered - Pellets",mec='#91D1C2FF',mfc='#91D1C2FF',ecolor='#91D1C2FF',barsabove=True, capsize=7,fmt='o')
ax8.tick_params(axis='y',labelsize=7)
ax8.set_title('(d) Only stacking',size=7,loc='left')
ax8.set_ylim(-.1,5.25)
ax8.set_ylabel('Times over-credited',size=7)
ax8.tick_params(axis='x',color='w',labelcolor='w')

fig.savefig('dec_1_23_over_crediting_projects_color_format_left_new.png',dpi=600)
# Out:
# /var/folders/qk/0hr6wzj547vcfzrvwtt5b9sc0000gn/T/ipykernel_20124/3743591543.py:9: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   ax10.errorbar(x_all, df_all_all, yerr=df_all_all_error,marker='D',ms=3,label='All',mec='#DC0000FF',mfc='#DC0000FF',ecolor='#DC0000FF',barsabove=True, capsize=7,fmt='o')
# /var/folders/qk/0hr6wzj547vcfzrvwtt5b9sc0000gn/T/ipykernel_20124/3743591543.py:10: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# ...
